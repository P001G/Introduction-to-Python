# %%
#Function to greet Kamau and welcome him to the assignment

def greet (firstname,lastname):
    return "Hello, {} {}, Welcome to my assignement".format(firstname,lastname)

salutation = greet ('John', 'Kamau')
print(salutation)
# Out:
# Hello, John Kamau, Welcome to my assignement

# %%
#Reading dataset AKI Dataset and describing it

import pandas as pd
import os #Not so sure what this does
#os.listdir() #Not so sure what this does

df = pd.read_excel('AKI Dataset.xlsx')
print(df.info())
print(df.shape)
#df.head()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 33 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 400 non-null    int64
#  1   Age                        400 non-null    int64
#  2   Gender                     400 non-null    object
#  3   MaritalStatus              400 non-null    object
#  4   Income                     400 non-null    int64
#  5   Region                     400 non-null    object
#  6   PolicyType                 400 non-null    object
#  7   PolicyStartYear            400 non-null    int64
#  8   PremiumMonthly             400 non-null    int64
#  9   ClaimsMade                 400 non-null    int64
#  10  ClaimsRejected             400 non-null    int64
#  11  LastClaimAmount            400 non-null    int64
#  12  RenewalStatus              400 non-null    object
# ...

# %%
df.describe().T
# Out:
#                            count        mean           std      min      25%  \
# CustomerID                 400.0    100.6725     58.334746      1.0     49.0
# Age                        400.0     44.1750     14.557444     18.0     32.0
# Income                     400.0  56322.3750  14367.926110  30261.0  43476.0
# PolicyStartYear            400.0   2018.1450      2.055368   2015.0   2016.0
# PremiumMonthly             400.0    147.8075     30.466884    100.0    122.0
# ClaimsMade                 400.0      2.2250      1.410443      0.0      1.0
# ClaimsRejected             400.0      1.0850      0.802737      0.0      0.0
# LastClaimAmount            400.0   1584.2500    873.920064      0.0    900.0
# CustomerSatisfaction       400.0      2.8725      1.386018      1.0      2.0
# NumberOfInquiriesLastYear  400.0      1.4500      1.095674      0.0      1.0
# CustomerFeedbackScore      400.0      5.3125      2.833711      1.0      3.0
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly_express as px

plt.bar(df['Region'], df['PolicyType'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
